# %%
import torch
import torch.optim as optim
import numpy as np

# %%
# Random seed to make results deterministic and reproducible
torch.manual_seed(0)

# %%
sentence = ("if you want to build a ship, don't drum up people together to "
            "collect wood and don't assign them tasks and work, but rather "
            "teach them to long for the endless immensity of the sea.")

# %%
# make dictionary
char_set = list(set(sentence))
char_dic = {c: i for i, c in enumerate(char_set)}

# %%
# hyper parameters
dic_size = len(char_dic)
hidden_size = len(char_dic)
sequence_length = 10  # Any arbitrary number
learning_rate = 0.1

# %%
# data setting
x_data = []
y_data = []
for i in range (0, len(sentence) - sequence_length):
    x_str = sentence[i:i + sequence_length]
    y_str = sentence[i + 1:i + sequence_length + 1]
    print(i, x_str, '->', y_str)

    x_data.append([char_dic[c] for c in x_str]) # x str to index
    y_data.append([char_dic[c] for c in y_str]) # y str to index

x_one_hot = [np.eye(dic_size)[x] for x in x_data]
# Out:
# 0 if you wan -> f you want
# 1 f you want ->  you want
# 2  you want  -> you want t
# 3 you want t -> ou want to
# 4 ou want to -> u want to
# 5 u want to  ->  want to b
# 6  want to b -> want to bu
# 7 want to bu -> ant to bui
# 8 ant to bui -> nt to buil
# 9 nt to buil -> t to build
# 10 t to build ->  to build
# 11  to build  -> to build a
# 12 to build a -> o build a
# 13 o build a  ->  build a s
# 14  build a s -> build a sh
# 15 build a sh -> uild a shi
# 16 uild a shi -> ild a ship
# 17 ild a ship -> ld a ship,
# 18 ld a ship, -> d a ship,
# 19 d a ship,  ->  a ship, d
# 20  a ship, d -> a ship, do
# 21 a ship, do ->  ship, don
# 22  ship, don -> ship, don'
# 23 ship, don' -> hip, don't
# 24 hip, don't -> ip, don't
# 25 ip, don't  -> p, don't d
# 26 p, don't d -> , don't dr
# 27 , don't dr ->  don't dru
# 28  don't dru -> don't drum
# 29 don't drum -> on't drum
# 30 on't drum  -> n't drum u
# 31 n't drum u -> 't drum up
# 32 't drum up -> t drum up
# 33 t drum up  ->  drum up p
# 34  drum up p -> drum up pe
# 35 drum up pe -> rum up peo
# 36 rum up peo -> um up peop
# 37 um up peop -> m up peopl
# 38 m up peopl ->  up people
# 39  up people -> up people
# 40 up people  -> p people t
# 41 p people t ->  people to
# 42  people to -> people tog
# 43 people tog -> eople toge
# 44 eople toge -> ople toget
# 45 ople toget -> ple togeth
# 46 ple togeth -> le togethe
# 47 le togethe -> e together
# 48 e together ->  together
# 49  together  -> together t
# 50 together t -> ogether to
# 51 ogether to -> gether to
# 52 gether to  -> ether to c
# 53 ether to c -> ther to co
# 54 ther to co -> her to col
# 55 her to col -> er to coll
# 56 er to coll -> r to colle
# 57 r to colle ->  to collec
# 58  to collec -> to collect
# 59 to collect -> o collect
# 60 o collect  ->  collect w
# 61  collect w -> collect wo
# 62 collect wo -> ollect woo
# 63 ollect woo -> llect wood
# 64 llect wood -> lect wood
# 65 lect wood  -> ect wood a
# 66 ect wood a -> ct wood an
# 67 ct wood an -> t wood and
# 68 t wood and ->  wood and
# 69  wood and  -> wood and d
# 70 wood and d -> ood and do
# 71 ood and do -> od and don
# 72 od and don -> d and don'
# 73 d and don' ->  and don't
# 74  and don't -> and don't
# 75 and don't  -> nd don't a
# 76 nd don't a -> d don't as
# 77 d don't as ->  don't ass
# 78  don't ass -> don't assi
# 79 don't assi -> on't assig
# 80 on't assig -> n't assign
# 81 n't assign -> 't assign
# 82 't assign  -> t assign t
# 83 t assign t ->  assign th
# 84  assign th -> assign the
# 85 assign the -> ssign them
# 86 ssign them -> sign them
# 87 sign them  -> ign them t
# 88 ign them t -> gn them ta
# 89 gn them ta -> n them tas
# 90 n them tas ->  them task
# 91  them task -> them tasks
# 92 them tasks -> hem tasks
# 93 hem tasks  -> em tasks a
# 94 em tasks a -> m tasks an
# 95 m tasks an ->  tasks and
# 96  tasks and -> tasks and
# 97 tasks and  -> asks and w
# 98 asks and w -> sks and wo
# 99 sks and wo -> ks and wor
# 100 ks and wor -> s and work
# 101 s and work ->  and work,
# 102  and work, -> and work,
# 103 and work,  -> nd work, b
# 104 nd work, b -> d work, bu
# 105 d work, bu ->  work, but
# 106  work, but -> work, but
# 107 work, but  -> ork, but r
# 108 ork, but r -> rk, but ra
# 109 rk, but ra -> k, but rat
# 110 k, but rat -> , but rath
# 111 , but rath ->  but rathe
# 112  but rathe -> but rather
# 113 but rather -> ut rather
# 114 ut rather  -> t rather t
# 115 t rather t ->  rather te
# 116  rather te -> rather tea
# 117 rather tea -> ather teac
# 118 ather teac -> ther teach
# 119 ther teach -> her teach
# 120 her teach  -> er teach t
# 121 er teach t -> r teach th
# 122 r teach th ->  teach the
# 123  teach the -> teach them
# 124 teach them -> each them
# 125 each them  -> ach them t
# 126 ach them t -> ch them to
# 127 ch them to -> h them to
# 128 h them to  ->  them to l
# 129  them to l -> them to lo
# 130 them to lo -> hem to lon
# 131 hem to lon -> em to long
# 132 em to long -> m to long
# 133 m to long  ->  to long f
# 134  to long f -> to long fo
# 135 to long fo -> o long for
# 136 o long for ->  long for
# 137  long for  -> long for t
# 138 long for t -> ong for th
# 139 ong for th -> ng for the
# 140 ng for the -> g for the
# 141 g for the  ->  for the e
# 142  for the e -> for the en
# 143 for the en -> or the end
# 144 or the end -> r the endl
# 145 r the endl ->  the endle
# 146  the endle -> the endles
# 147 the endles -> he endless
# 148 he endless -> e endless
# 149 e endless  ->  endless i
# 150  endless i -> endless im
# 151 endless im -> ndless imm
# 152 ndless imm -> dless imme
# 153 dless imme -> less immen
# 154 less immen -> ess immens
# 155 ess immens -> ss immensi
# 156 ss immensi -> s immensit
# 157 s immensit ->  immensity
# 158  immensity -> immensity
# 159 immensity  -> mmensity o
# 160 mmensity o -> mensity of
# 161 mensity of -> ensity of
# 162 ensity of  -> nsity of t
# 163 nsity of t -> sity of th
# 164 sity of th -> ity of the
# 165 ity of the -> ty of the
# 166 ty of the  -> y of the s
# 167 y of the s ->  of the se
# 168  of the se -> of the sea
# 169 of the sea -> f the sea.

# %%
# transform as torch tensor variable
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)
# Out:
# /var/folders/l9/13yp2vrd6tq7yycbp1vv4lh00000gn/T/ipykernel_64564/1455435457.py:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:277.)
#   X = torch.FloatTensor(x_one_hot)

# %%
# declare RNN + FC
class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, layers):
        super(Net, self).__init__()
        self.rnn = torch.nn.RNN(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        self.fc = torch.nn.Linear(hidden_dim, hidden_dim, bias=True)

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x)
        return x

net = Net(dic_size, hidden_size, 2)

# %%
# loss & optimizer setting
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), learning_rate)

# %%
# start training
for i in range(100):
    optimizer.zero_grad()
    outputs = net(X)
    loss = criterion(outputs.view(-1, dic_size), Y.view(-1))
    loss.backward()
    optimizer.step()

    results = outputs.argmax(dim=2)
    predict_str = ""
    for j, result in enumerate(results):
        # print(i, j, ''.join([char_set[t] for t in result]), loss.item())
        if j == 0:
            predict_str += ''.join([char_set[t] for t in result])
        else:
            predict_str += char_set[result[-1]]

    print(predict_str)
# Out:
# gfgfgfifiigifgiifgffiiififggifgiifgf.figfggffiipfifgiffifgifgiiififififiifiiififgiifgiifffigfifgifififgigfififiiiiiiifffgfgifgiiigfifgifgiiiiiifgfifififwfifififgifwfffggififififfi
# eeeeeeeeeeeeeeeeeleeeeeeeleeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeleeeeeeeeeeeeeeeeeeeeeleeeeeeeeeeeeeeeeeeeeeleeeeeeeleeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeleeeeeleeeeeeeeeeeee
# t t  t   t to tt  t ttt tt  t t t    t t  t  t ttt  tt  t t tttt  tt ttt  ttt t   t    t  tt t  t ttt  t  tt  ttt t t tt  tt ttt t    t tt t  t t tt  tt   ttttt   t tt tttt   tttt
#   r epriepe     pp  pp  pp    p       e  p       p   p   p  pp     p   p  ppp   p epa e e  p p p  p   pp   p   pw epp     p   e   i     p   pp  p  u  p e      pi  pp  p     p    p
#                   sa    a   a   a                    s          s      a s  aa    a     a a     s   s a a a a a   a a       a    a      a       a       a    a    s  saa  a  a   a
#    o      o o  e  eo o     o       o       eo  o  o        o     o eo h        o     o o    o       e        o     o   o o  o     o       e  o    eo o o     o    o   o   o o   o
#   totototottotoeoteototoe e totot  o ottotoeotttttotoe e ttotoeototeototottttoto  e t eot ttottetotoe t totot   tototo  eo totoe totoetteteototetoe eotototototttottttoeoeotoeo oeo
#       t     lt   t ttot   t tot   t    tltt  t   tot   t  ttto  t ttot t   lttt   t t   t t tto tlto  t t t   t t   t t t   t t  t     ltt  t tot t t t t     to   t ttt   t t t t
#   t        to    l     o  t toto       to    tttoto       to    l t  to   tlt       d   t tt  o tl  d d   t t t t t        to    t to tlt   l t to  t to o o  t t t  t       t
#        o   to   to     o    t  o       to           o     to    o    to   to   o           t  o to    t  o o    t  o     o to       o to    o          o   o  to           to o   o
#   t        to   to  t       t          t           t      to         to   t   to    t     tt    to  , t   to  u t          to    t    to        t t     t     to     t     to
#   t t t t  tot  t e tot u u t t s t e  tme   t   t t e t  tot      t toe  tme tot   the t tt e  toe , tot tot t t t t t e  toe d toe  tot  t  t t the t t t   t   t  t t   the tht
#   tot toe  toe  t e tothe , tot t toe  toet  toeltot e e etoe e    t toe  toe tot t toe t tthe etoe , toeotoe t t tht the etoe t toe etot e  et t toe tot to  toe t  toel  toe tht
#   toe t et toe  t e tothe , toe t toe  toet  toeltoe e e etoe e ee t toe  toe toe t toe t tthe etoe , tot toe , tot t the etoe t toe  toe e   t t toe tot toe t e t  toele toe the
# m toe t etotoe' t e tot e e toe't toet t et  t elt e e e  toe'   e t toel tot toe't toe t et e  toe , t t toe t tot t t el toe t toel tos'    t t toe tot e   t e tt toet  toe t t
# m toelt  totoe  t e tothe , toe't t etotl l  to lths't el toe u le t to l tot toe t t t , lthe  toe', , d to  , tos t thel toe s to l toe u t t t the t t t   t e tt to lt the thtc
# m to lt et t  l sl, t them, to lt t etotler  tl rth lt er to lo le t to lot t to lt t   t lthel to k, t d to  , l s t th l to mo to l to lo l t t th lt d er  t e mt th ln to lt tm
# m toelt  t toel t e totheme toslt to t tlele tlemtoe t et toelo eemt to lotod toelt t   t ethem toek, t d to k, l t t them toemo toem toel nl t t themtod er  t e td thetn toemt tm
# m toemt et toslotkd tcthek, to 't dhem tlefe tlemthe s es toelo lent to kotot dhtkt d eht dthem tosktndnd to k, b t t t em toecs toem tosken' t t t emtothen  tke tt thetn themthtk
# k toeltoel toel lee tothek, do 't do l toele nlentoels en toelo  eno to lotod to 't do  t etoel to k, toeoto  , lol t shel toemo toek toelsn el l toeltoeoen  to ent moelo toelthac
# m tonkt st tonl ild tntkek, to 't to p t'elt tlentonlt en to lon ena tonlotlt to 't to ct dthep to k, toa tonk, d p t thep to ko toem to l,ndetoa thestnd en  tp ent toeps themthtc
# m t tptnst thal tmd tcthend ton't do m tldtlttleit d t et thnlo  eit tonl tpd to 't dn mt dt es thshtntnd tonk, d t t t es thsch thes thal,nd t d t estsd es st   tdit  tn thesthtc
# m tonc, nt dhnl  le ththen, don't do m tletl ile thn t en th lo 'e thdonm tnd don't dn cd dthec th k, tnd donk, d i t thec thnch thec thnlu ' ton t entnd en  tk  ndhth mn thecthtc
# m tonl, nthdo l ile tothem, don't doem tletlnn' nto  rhen to lo le todonlotnd don't do hd dthe  to k, tnd donk, b t d the  tonch toen to lo ' to 't entnd en  t'  ndhdoemo the thtc
# m tonltontoto lutld tothem, don't doem tnele toento  then to lo  e thdonlotnd don't dos t ethe  tos s tnd donk, b t t the  tonco toe  to l, d mor toentnd en itk  nd toemo toe thtc
# m tonlt sd to lutld tnthem, donlt doem trele tle to  t en to lo eect tonloand donlt dns t ethec tos s tnd donk, b t t thec tosco toec to l, detol themtndees itc end to tf the thtc
# potouldant to luild a ship, don't doum ap feople togethe  to lol ect worl and don't wssign them tosks and work, but aathem toach them to long for themandless tm ersity tf themaesc
# potouldant to build a ship, don't doum ap feople togethe  to bollect worp and don't dssign the  tosks and dork, but aathe  toach the  to bong for the andless im ensity of the aeac
# potouedant to build a ship, don't doum ap people to ethen to lollect worp and don't dssign them tosks and dork, but aathen toach the  to long for themafdless tm ensity of the aeac
# potou dart to luild a ship, don't doum up oeople torethe  to lol ect worp and don't dssign them tosks and dork, but aathem toach them to long for themandless tm ensity of themaeac
# potou dant to build a ship, don't doum up people togethe  to lollect aord and don't dssign the  tosks and dork, but aathe  toach the  to long for the andless im e sity of the seac
# potou dant to build a ship, don't doum up people togethe  to lollect word and don't dssign them tosks and dork, but aathe  toach the  to long for themandless tm ensity of the seac
# potou dart to buile a ship, don't aoum up people togethe  ta lollect word and don't assign them tasks and dork, but tathe  taach them ta long for themendless tm e sity of the aeac
# potouldant to build a ship, don't doum up people togethe  to lollect word and don't dssign the  tosks and work, but aathen toach the  to bong for thecandless im ersity of the aeac
# potou dant to build a ship, don't doum up people together te lollect word and don't dssign the  tosks and work, but aather teach the  to long for the endless immensity of the seac
# potou dart to build a ship, don't doum up people to ethe  to lollect word and don't assign them tosks and work, but aather toach them to long for themendless immensity of the seac
# potou dant to build a ship, don't doum up people together to lol ect word and don't dssign them tosks and work, but aather toach them to long for the sndless immensity of the seac
# potou dant to build a ship, don't doum ul people togethe  th lollect word and don't dssign them tasks and work, but aathe  thwch them ta long for themendle s immensity of the seac
# potou want to build anship, don't aoum up people together to lol ect word and won't assign them tosks and work, but aather toach them to long for therendless immersity of theraeac
# potou want to build a ship, don't aoum up people together to bhllect aord and don't assign them tasks and work, but aather toach them ta long for themendless ammersity of the eeas
# potou oant to luild a ship, don't doum up people togethe  to lollect word and don't ansign them tosks and work, but aathe  toach them to long for themendless immefsity of themeeac
# motou oant to luild a ship, don't doum up people together to lollect word and don't dssign the  tosks and work, but aather toach the  to long for the sndless immensity of therskan
# motou want to luild a ship, don't drum up people together to lollect word and don't dssign the  tosks and work, but aather toach the  to long for the endless immersity of therseas
# motou dant to luild a ship, don't drum up people together te lollect word and don't dssign them tesks and work, but tathe  teach them te long for themendless immensity of themeiac
# motou want to build a ship, don't doum up people together to bollect word and won't dssign them tosks and work, but aathe  toach them to bong for themendless immensity of themeeac
# motou want to build a ship, don't aoum up people together to bollect word and won't assign them tasks and work, but aathe  toach them ta bong for themendless immensity of the eeac
# totou want to build a ship, don't arum up people together to collect word and don't assign them tosks and work, but aather toach them to cong for themendless immensity of the siac
# motou want to cuild a ship, don't drum up people together to collect word and don't dssign them tasks and work, but aather toach them ta cong for the sndless immensity of the sean
